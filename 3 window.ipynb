# %%
import pydicom as dicom
import numpy as np
import scipy 
import os

# %%
def get_contour_file(path):
    
    # handles `/` missing
    if path[-1] != '/': path += '/'
    
    # get .dcm contour file
    fpaths = [path + f for f in os.listdir(path) if '.dcm' in f]
    n = 0
    for fpath in fpaths:
        f = dicom.read_file(fpath)
        if 'ROIContourSequence' in dir(f):
            contour_file = fpath.split('/')[-1]
            n += 1
    if n > 1: warnings.warn("Many Files")
    if contour_file is None: print("No contour files in the selected directory")
    return contour_file

# %%
def print_roi_names(path, file):
    
    # checks if the path contains '/' and reads the file
    if path[-1] != '/': path += '/'
    d=dicom.dcmread(path + file)
    
    n = len(d.StructureSetROISequence)
    print('Il y a', n, 'structures dans le fichier:')

    for i in range(n):
        print('  ', i, ':', d.StructureSetROISequence[i].ROIName)

# %%
def plotcontour(img_arr, contour_arr, figsize=(20, 20)):
    """
    Shows 2d MR img with contour
    Inputs
        img_arr: 2d np.array image array with pixel intensities
        contour_arr: 2d np.array contour array with pixels of 1 and 0
    """

    masked_contour_arr = np.ma.masked_where(contour_arr == 0, contour_arr)
    plt.figure(figsize=figsize)
    plt.subplot(1, 2, 1)
    plt.imshow(img_arr, cmap='hot', interpolation='none')
    plt.subplot(1, 2, 2)
    plt.imshow(img_arr, cmap='hot', interpolation='none')
    plt.imshow(masked_contour_arr, cmap='cool', interpolation='none', alpha=0.6)
    plt.show()

# %%
m_path='imgs/'
contour_file = get_contour_file(m_path)
print_roi_names(m_path, contour_file)
# Out:
# Il y a 2 structures dans le fichier:
#    0 : External
#    1 : ext+1.6cm

# %%
a=dicom.dcmread(m_path + contour_file)
print(a.ROIContourSequence)
a.ROIContourSequence[1].ContourSequence
# Out:
# [(0021, 0010) Private Creator                     LO: 'NUCLETRON'
# (0021, 1000) Private tag data                    UI: 1.3.6.1.4.1.2452.6.758510512.1171258812.3936947857.2645619669
# (3006, 002a) ROI Display Color                   IS: [255, 173, 91]
# (3006, 0040)  Contour Sequence   183 item(s) ----
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1153380461.1330345744.3177375909.1484819030
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "1"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1834836726.1108121275.2604872626.2308775175
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "2"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.463503138.1164132480.230039194.2894963864
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "3"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.4095275812.1255279568.2754307261.1031082457
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "297"
#    (3006, 0048) Contour Number                      IS: "4"
#    (3006, 0050) Contour Data                        DS: Array of 891 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.98058538.1121464469.3576781980.1714206243
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "5"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3894703054.1211150219.945422239.1552048371
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "6"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1058469510.1231525399.3296043698.1810928901
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "7"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3550417111.1260261234.3905653401.2644005269
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "8"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2321106520.1278671676.1934605757.945317901
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "9"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1777312475.1165906536.4293442741.1693835841
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "10"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1859472849.1278142776.3437156745.818395840
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "11"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1600667262.1304413675.3791027365.998454734
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "12"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3940357840.1169301111.2289935531.989433723
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "13"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.624644616.1179332674.3701864636.3816084798
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "14"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3184695614.1133702188.2518206346.2325583661
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "15"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1942094053.1221472219.2661397694.144657472
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "16"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3841782111.1310301242.2635014319.281447676
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "17"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.4045677969.1096995916.1771620233.4167353313
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "18"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.381622645.1203222900.4153930117.139387799
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "19"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.761877998.1076265164.1415784580.1735468057
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "20"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.878423030.1332533995.3652188545.3381778275
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "21"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.442906051.1124282206.1070664332.3851241586
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "22"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.459725012.1242380627.3077797282.1525388481
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "23"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3737777351.1249633292.3693922721.224029303
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "24"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.462071726.1165900872.177468289.272432598
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "25"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1155250930.1080706111.857508751.178610418
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "26"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.251241081.1251867528.377060786.908919502
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "27"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3745555028.1074843281.1443481746.2612491934
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "28"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2308785125.1232728670.3203543694.3559356050
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "29"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1943383930.1079172023.3113246096.4000616323
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "30"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.187617876.1131208868.2001500838.4080722765
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "31"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.636520000.1156102463.2130697863.1328169452
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "32"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.497776770.1244585179.1080278687.983953747
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "33"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2081019018.1151674445.387081103.4136235296
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "34"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2846661434.1233505365.3568333214.617598624
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "35"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3703750636.1218602038.1879067308.2747612073
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "36"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.209398288.1303901082.496586637.2210526513
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "37"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1091426730.1204482001.3838667186.1789155430
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "38"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.341346454.1266334359.19033733.1700709970
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "39"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.813222295.1077132647.82204553.3374046999
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "40"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.710890670.1160110040.2052570533.286033100
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "355"
#    (3006, 0048) Contour Number                      IS: "41"
#    (3006, 0050) Contour Data                        DS: Array of 1065 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3706717260.1321667834.1131632813.1479797243
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "42"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3350984487.1129320386.2951505815.1039515136
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "43"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3416840125.1202232764.2600788882.1775917312
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "44"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1175693020.1338153834.3265542833.3199569091
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "45"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1565401395.1119189808.1267129746.93481516
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "46"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1676131850.1220555986.4204368553.1327243104
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "47"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.4103417369.1140314574.1638463927.75547577
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "48"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2802122030.1110484273.883896508.32020044
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "49"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.44827679.1313211848.4133618094.2627849073
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "50"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.234707024.1203560287.3979194253.2712166592
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "51"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2035975771.1113147776.1488280762.1408440398
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "52"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2647822873.1247525915.449561022.2067635250
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "53"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.545489110.1119472516.317420172.3685557060
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "54"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2848884242.1130888756.707601550.3942466942
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "55"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2829129822.1266172045.2971953066.708083587
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "56"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2586506287.1090365916.3120540073.661319981
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "57"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3122579234.1272352871.846652841.3659263191
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "58"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.682824639.1084418725.2793652658.1078079170
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "59"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.890353113.1229565966.3965412241.1228135984
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "60"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1509738941.1285851518.1468969111.3899702920
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "61"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1665721733.1296786312.3248267197.4291357914
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "62"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2976477886.1266603212.2382204555.4214208662
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "63"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2049706522.1216878530.606462142.3661930099
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "64"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3540837195.1335242207.3686964640.2688400599
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "65"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1169979811.1213812754.321352619.2033939395
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "66"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3092940152.1240115397.1202723237.3293430263
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "67"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1043807124.1162709060.2261651119.832108967
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "68"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.915918179.1147726561.2172716204.1482251207
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "69"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3133549691.1190786813.561565056.3631703414
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "70"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3417259426.1209716570.2112581564.3570042187
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "71"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3365944212.1339664492.1391842989.4085853110
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "72"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.958747159.1149454194.1884473782.2099712227
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "73"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3386067043.1220927322.330950801.2274778025
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "74"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.611151804.1319713738.2568012963.3977381578
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "75"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3119597847.1106275300.2028151219.667680973
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "76"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2344107693.1189269021.2121210302.478456054
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "77"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3406590977.1332204472.1476373426.2001976053
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "351"
#    (3006, 0048) Contour Number                      IS: "78"
#    (3006, 0050) Contour Data                        DS: Array of 1053 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3033356751.1289284157.1184872373.3974980234
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "79"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.454529456.1114956865.4031121836.1511287771
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "80"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2636910380.1136631549.3420037810.94338647
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "81"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2548052117.1092697158.2268149643.3225219055
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "82"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1194857274.1184733165.1971670412.618149086
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "83"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.4091149375.1265111263.3393005230.2001182172
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "84"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2904651897.1152619793.2713836728.1830836773
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "353"
#    (3006, 0048) Contour Number                      IS: "85"
#    (3006, 0050) Contour Data                        DS: Array of 1059 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.426128306.1168148039.1743666853.329907110
#       ---------
# ...
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "180"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1942094053.1221472219.2661397694.144657472
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "181"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3184695614.1133702188.2518206346.2325583661
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "182"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.624644616.1179332674.3701864636.3816084798
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "183"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3940357840.1169301111.2289935531.989433723
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "184"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1600667262.1304413675.3791027365.998454734
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "185"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1859472849.1278142776.3437156745.818395840
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "186"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1777312475.1165906536.4293442741.1693835841
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "187"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2321106520.1278671676.1934605757.945317901
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "188"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3550417111.1260261234.3905653401.2644005269
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "189"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1058469510.1231525399.3296043698.1810928901
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "190"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3894703054.1211150219.945422239.1552048371
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "191"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.98058538.1121464469.3576781980.1714206243
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "192"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.4095275812.1255279568.2754307261.1031082457
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "193"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.463503138.1164132480.230039194.2894963864
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "194"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1834836726.1108121275.2604872626.2308775175
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "195"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1153380461.1330345744.3177375909.1484819030
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "196"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2270548177.1128302077.2889758092.425279452
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "197"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3447717997.1259726963.2735651476.514112655
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "198"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.4150432179.1211443226.3788301757.3112399974
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "199"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2059709119.1314420252.1589197482.2593933172
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "200"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.765535656.1095296901.140116158.1162230493
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "201"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3596176035.1200720545.2045097894.2279121303
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "202"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.3136264268.1306520119.3294838935.3369059113
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "203"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1256517795.1208066418.1765671829.3636039695
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "204"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.2950556860.1301108562.3012471426.2501280803
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "205"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.207237008.1256652056.446902146.2526724198
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "206"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.92044257.1093521497.693722541.193835586
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "207"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
#    (3006, 0016)  Contour Image Sequence   1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1292269668.1105845885.2742603430.1994733092
#       ---------
#    (3006, 0042) Contour Geometric Type              CS: 'CLOSED_PLANAR'
#    (3006, 0046) Number of Contour Points            IS: "199"
#    (3006, 0048) Contour Number                      IS: "208"
#    (3006, 0050) Contour Data                        DS: Array of 597 elements
#    ---------
# (3006, 0084) Referenced ROI Number               IS: "2"]
# <Sequence, length 208>

# %%
#verification contour sur CT
RIO=1
contour=108
g=int(contour)
f=int(RIO)

d=np.zeros((512,512))
d1=np.zeros((512,512))

for u in range (g-2,g+2):
     contour_dataset=a.ROIContourSequence[f].ContourSequence[u]
     img_ID = contour_dataset.ContourImageSequence[0].ReferencedSOPInstanceUID
     img = dicom.read_file(path +'CT'+ img_ID + '.dcm')
     p=img.pixel_array
     x_spacing, y_spacing = float(img.PixelSpacing[0]), float(img.PixelSpacing[1])
     origin_x, origin_y, _ = img.ImagePositionPatient 
     
     c1=contour_dataset.ContourData
     points=int(a.ROIContourSequence[f].ContourSequence[u].NumberOfContourPoints) 
     print(points)
     for i in range (0,points-1):
     
          y1=np.int((around((c1[(i*3)+1]))-origin_y)/ y_spacing)
          x1=np.int((around((c1[(i*3)]))-origin_x)/ x_spacing)
          y2=np.int((around((c1[((i+1)*3)+1]))-origin_y)/ y_spacing)
          x2=np.int((around((c1[((i+1)*3)]))-origin_x)/ x_spacing)
          d[y1,x1]=1000
          if x1 != x2 :
              a=((y1-y2)/(x1-x2))
              b=0.5*((y1+y2)-(a*(x1+x2)))
         
              if x1<x2 :
                  for k in range(x1-1,x2+1):
                    y=np.int(around((a*k)+b))
                    d1[y,k]=1000
             
              if x1>x2:
                  for e in range(x2-1,x1+1):
                      y=np.int(around(((a*e+b))))
                      d1[y,e]=1000
              if x1==x2:
            
                
                     d1[y1,x1]=1000
                     
                    
          if y1 != y2 :
                
              a=((x1-x2)/(y1-y2))
              b=0.5*((x1+x2)-(a*(y1+y2)))
         
              if y1<y2 :
                  for k in range(y1-1,y2+1):
                    x=np.int(around((a*k)+b))
                    d1[k,x]=1000
             
              if y1>y2:
                  for e in range(y2-1,y1+1):
                      x=np.int(around(((a*e+b))))
                      d1[e,x]=1000
              if y1==y2:
            
                
                     d1[y1,x1]=1000
     i=0               
     y1=np.int((around((c1[(i*3)+1]))-origin_y)/ y_spacing)
     x1=np.int((around((c1[(i*3)]))-origin_x)/ x_spacing)
     i=points-2
     y2=np.int((around((c1[((i+1)*3)+1]))-origin_y)/ y_spacing)
     x2=np.int((around((c1[((i+1)*3)]))-origin_x)/ x_spacing)
     d1[y1,x1]=1000
     if x1 != x2 :
              a=((y1-y2)/(x1-x2))
              b=0.5*((y1+y2)-(a*(x1+x2)))
         
              if x1<x2 :
                  for k in range(x1-1,x2+1):
                    y=np.int(around((a*k)+b))
                    d1[y,k]=1000
             
              if x1>x2:
                  for e in range(x2-1,x1+1):
                      y=np.int(around(((a*e+b))))
                      d1[y,e]=1000
              if x1==x2:
            
                
                     d1[y1,x1]=1000
                     
                    
     if y1 != y2 :
                
              a=((x1-x2)/(y1-y2))
              b=0.5*((x1+x2)-(a*(y1+y2)))
         
              if y1<y2 :
                  for k in range(y1-1,y2+1):
                    x=np.int(around((a*k)+b))
                    d1[k,x]=1000
             
              if y1>y2:
                  for e in range(y2-1,y1+1):
                      x=np.int(around(((a*e+b))))
                      d1[e,x]=1000
              if y1==y2:
            
                
                     d1[y1,x1]=1000
d2=d1+d       
d4=np.zeros((512,512))
for i in range (0,512):
    for j in range(0,512):
        if d2[i,j]>0:
            
            for a in range (j,512):
                 if d2[i,a]>0:
                    for e in range (j,a):
                        d4[i,e]=1000
d3=np.zeros((512,512))
for j in range (0,512):
    for i in range(0,512):
        if d2[i,j]>0:
            
            for a in range (i,512):
                 if d2[a,j]>0:
                    for e in range (i,a):
                        d3[e,j]=1000
d5=np.zeros((512,512))                        
for i in range (0,512):
    for j in range(0,512):
        if d3[i,j]>0 and d4[i,j]>0:
            d5[i,j]=1000
        
plot2dcontour(p,d5)

# %%
roi_names(contour_file)
a=dicom.dcmread(path + '/' + contour_file)

# %%
a=dicom.dcmread(path + '/' + contour_file)
a.ROIContourSequence[1].ContourSequence

# %%
RIO=1
N_contours=208
mm=np.zeros((128,128,128))


   
for pp in range (0,N_contours-1):
     g=int(pp)
     f=int(RIO)

     d=np.zeros((128,128))
     d1=np.zeros((128,128))
     for u in range (g-2,g+1):
         
         a=dicom.dcmread(path + '/' + contour_file)
         contour_dataset=a.ROIContourSequence[f].ContourSequence[u]
   
         img = dicom.read_file('imgs/spect.DCM')
         p=img.pixel_array
         x_spacing, y_spacing,z_spacing = float(img.PixelSpacing[0]),float(img.PixelSpacing[0]), float(img.SliceThickness)
         origin_x, origin_y,origin_z = img.DetectorInformationSequence[0].ImagePositionPatient
         c1=contour_dataset.ContourData
         nn=128-(around((c1[2]+origin_z)/z_spacing))
         v_pixel=x_spacing*y_spacing*z_spacing
         points=int(a.ROIContourSequence[f].ContourSequence[u].NumberOfContourPoints)  
         for i in range (0,points-1):
     
               y1=np.int(((c1[(i*3)+1])-origin_y)/ y_spacing)
               x1=np.int((around((c1[(i*3)]))-origin_x)/ x_spacing)
               y2=np.int((around((c1[((i+1)*3)+1]))-origin_y)/ y_spacing)
               x2=np.int((around((c1[((i+1)*3)]))-origin_x)/ x_spacing)
               d[y1,x1]=1000
               

               if x1 != x2 :
                    a=((y1-y2)/(x1-x2))
                    b=0.5*((y1+y2)-(a*(x1+x2)))
         
                    if x1<x2 :
                       for k in range(x1,x2+1):
                           y=np.int(around((a*k)+b))
                           d1[y,k]=1000
              
                    if x1>x2:
                       for e in range(x2,x1+1):
                           y=np.int(around(((a*e+b))))
                           d1[y,e]=1000
                    if x1==x2:
            
                
                           d1[y1,x1]=1000
                     
                    
               if y1 != y2 :
                
                   a=((x1-x2)/(y1-y2))
                   b=0.5*((x1+x2)-(a*(y1+y2)))
         
                   if y1<y2 :
                          for k in range(y1,y2+1):
                            x=np.int(around((a*k)+b))
                            d1[k,x]=1000
             
                   if y1>y2:
                          for e in range(y2,y1+1):
                              x=np.int(around(((a*e+b))))
                              d1[e,x]=1000
                   if y1==y2:
            
                
                     d1[y1,x1]=1000
                    
         i=0               
         y1=np.int((around((c1[(i*3)+1]))-origin_y)/ y_spacing)
         x1=np.int((around((c1[(i*3)]))-origin_x)/ x_spacing)
         i=points-2
         y2=np.int((around((c1[((i+1)*3)+1]))-origin_y)/ y_spacing)
         x2=np.int((around((c1[((i+1)*3)]))-origin_x)/ x_spacing)
         d1[y1,x1]=1000
         if x1 != x2 :
                  a=((y1-y2)/(x1-x2))
                  b=0.5*((y1+y2)-(a*(x1+x2)))
         
                  if x1<x2 :
                      for k in range(x1,x2+1):
                        y=np.int(around((a*k)+b))
                        d1[y,k]=1000
             
                  if x1>x2:
                      for e in range(x2,x1+1):
                          y=np.int(around(((a*e+b))))
                          d1[y,e]=1000
                  if x1==x2:
            
                
                         d1[y1,x1]=1000
                     
                    
         if y1 != y2 :
                
                  a=((x1-x2)/(y1-y2))
                  b=0.5*((x1+x2)-(a*(y1+y2)))
         
                  if y1<y2 :
                      for k in range(y1,y2+1):
                        x=np.int(around((a*k)+b))
                        d1[k,x]=1000
             
                  if y1>y2:
                      for e in range(y2,y1+1):
                          x=np.int(around(((a*e+b))))
                          d1[e,x]=1000
                  if y1==y2:
            
                
                         d1[y1,x1]=1000
     d2=d1+d       
     d4=np.zeros((128,128))
     for i in range (0,128):
         for j in range(0,128):
             if d2[i,j]>0:
            
                 for a in range (j,128):
                      if d2[i,a]>0:
                         for e in range (j,a):
                             d4[i,e]=1000
     d3=np.zeros((128,128))
     for j in range (0,128):
         for i in range(0,128):
             if d2[i,j]>0:
            
                 for a in range (i,128):
                      if d2[a,j]>0:
                         for e in range (i,a):
                             d3[e,j]=1000
     d5=np.zeros((128,128))                        
     for i in range (0,128):
         for j in range(0,128):
             if d3[i,j]>0 and d4[i,j]>0:
                 d5[i,j]=1000
     
     mm[int(nn)]=d5

# %%
i=50
plotcontour(p[i],mm[i])

# %%
for k in range (0,128):
           if np.sum(mm[k])>0:
             mm[k-1]=mm[k]
             #mm[k-2]=mm[k]
             break
for k in range (0,127):
           if np.sum(mm[127-k])>0:
              mm[127-k+1]=mm[127-k]
             #mm[k-2]=mm[k]
              break
mn=np.zeros((128,128,128))

for k in range (0,128):
    for i in range(0,128):
        for j in range(0,128):
            mn[k,i,j]=mm[i,k,j]
            
sp=np.zeros((128,128,128))
x=dicom.dcmread('imgs/spect.DCM')
p=x.pixel_array
for k in range (0,128):
    for i in range(0,128):
        for j in range(0,128):
            sp[k,i,j]=p[i,k,j]
i=65          
plot2dcontour(sp[i],mn[i])

# %%
N=0
pc=np.zeros((128,128,128))
for k in range (0,128):
    for i in range(0,128):
        for j in range(0,128):
             if mm[k,i,j]>0 :
                  pc[k,i,j]=p[k,i,j]
                  N=N+1
                    
v_f=(N*v_pixel) *10**(-3)                
print('le volume est de=',v_f  )                 
cp=np.sum(pc)
hour=int(img.AcquisitionTime[0:2])-14
min=int(img.AcquisitionTime[2:4])-59
t_s1=(23+hour)*60+min+10        #temps de comencent d'acqusition detecteur1  (min)
t_aq=int(img.RotationInformationSequence[0].ActualFrameDuration)*0.5/10**3         #duré d'acqusition (min)
t_p=792     #periode physique de 123-I (min)
#----------------------------------------------------------------------------------
A_inj_s1 =0.001093*16+(v_f+(-16))*0.000298   # l'activité de la suringue pliene (mCi)
t_s11=1       #temps de mesure  l'activité de la suringue pliene (min)
A_ss1=0   # l'activité de la suringue vide (mCi)
t_ss1=0       #temps de mesure  l'activité de la suringue vide (min)

A_ss1=(A_ss1 * exp((log(2)*t_ss1)/t_p))
A_inj_s1=(A_inj_s1 * exp((log(2)*t_s11)/t_p))
#correction de l'activité exact injecté  .
A_s1=A_inj_s1-A_ss1
#----------------------------------------------------------------------------------
#----------------------------------------------------------------------------------
A_inj_s2 =0.001093*8 +(v_f+(-8))*0.000298   # l'activité de la suringue pliene (mCi)
t_s2=1       #temps de mesure  l'activité de la suringue pliene (min)
A_ss2=0   # l'activité de la suringue vide (mCi)
t_ss2=0       #temps de mesure  l'activité de la suringue vide (min)

A_ss2=(A_ss2 * exp((log(2)*t_ss2)/t_p))
A_inj_s2=(A_inj_s2 * exp((log(2)*t_s2)/t_p))
#correction de l'activité exact injecté  .
A_s2=A_inj_s2-A_ss2
#----------------------------------------------------------------------------------
A_inj_fond =2.04   # l'activité de la suringue pliene (mCi)
t_fond=1      #temps de mesure  l'activité de la suringue pliene (min)
A_sfond=0  # l'activité de la suringue vide (mCi)
t_sfond=4      #temps de mesure  l'activité de la suringue vide (min)

A_sfond=(A_sfond * exp((log(2)*t_sfond)/t_p))
A_inj_fond=(A_inj_fond * exp((log(2)*t_fond)/t_p))
#correction de l'activité exact injecté  .
A_fond=A_inj_fond-A_sfond
#----------------------------------------------------------------------------------


#----------------------------------------------------------------------------------






#A_total=A_pd+A_lf+A_lc+A_foie+A_fond+A_pg
A_total=A_fond
# l'activité au moment de commencement d'acquisition  .

# l'activité au moment de commencement d'acquisition  .
A_01=A_total * exp((-log(2)*t_s1)/t_p)


# l'activité moyenne entre le debut et la fin d'acquisition mCi .


# nombre de coups par seconde    
cps=cp/(t_aq*2*60)
# l'activité moyenne entre le debut et la fin d'acquisition (MBq)  .
A_m1=(A_01 *37*(t_p/log(2))* (1-exp(-log(2)*t_aq/t_p)))/t_aq

A_mesuré=cps/62.5
print('activité réelle =',A_m1)
print('activité mesuré',A_mesuré)
v=abs(A_mesuré-A_m1)*100/A_m1
print('variation relative',v,'%')

# %%
img

# %%
int(img.AcquisitionTime[0:2])-14
